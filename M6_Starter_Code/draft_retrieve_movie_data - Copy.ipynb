# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Set environment variables from the .env in the local environment
load_dotenv()

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")

# %%
print(nyt_api_key)
# Out:
# YXVxHe0TcAH2dCIpYZnCZ2GhtlVrmg6y

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL
#query_url = f"{url}api-key={nyt_api_key}&fq={filter_query}&sort={sort}&fl={field_list}&begin_date={begin_date}&end_date=[end_date]"
query_url = (
    f"{url}api-key={nyt_api_key}&begin_date={begin_date}&end_date={end_date}"
    + f'&fq={filter_query}&sort={sort}&fl={field_list}')
response = requests.get(query_url)
print(query_url)
# Out:
# https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=YXVxHe0TcAH2dCIpYZnCZ2GhtlVrmg6y&begin_date=20130101&end_date=20230531&fq=section_name:"Movies" AND type_of_material:"Review" AND headline:"love"&sort=newest&fl=headline,web_url,snippet,source,keywords,pub_date,byline,word_count

# %%
print(response)
# Out:
# <Response [200]>

# %%
#reviews_list = []


#for results in

# %%
# Create an empty list to store the reviews
reviews_list = []

# loop through pages 0-19
for page in range(0,20):

    # create query with a page number
    # API results show 10 articles at a time
    #offset = page * 10

    #query_url = f"{url}q={filter_query}&sort={sort}&fl={field_list}&begin_date={begin_date}&end_date={end_date}&api-key={nyt_api_key}&offset={offset}"
    #query_url = (
    #f"{url}api-key={nyt_api_key}&begin_date={begin_date}&end_date={end_date}"
    #+ f'&fq={filter_query}&sort={sort}&fl={field_list}')
    page_url = f"{query_url}&page={page}"
   
    # Make a "GET" request and retrieve the JSON
    reviews = requests.get(page_url).json()
    
    # Add a twelve second interval between queries to stay within API query limits
    time.sleep(12)
    
    # # Try and save the reviews to the reviews_list
    try: 
        for review in reviews["response"]["docs"]:
            reviews_list.append(review)
        print(f"checked page{page}")
    except:
        print(f"No results for page {page+1}, breaking from loop")
        break
# Out:
# checked page0
# checked page1
# checked page2
# checked page3
# checked page4
# checked page5
# checked page6
# checked page7
# checked page8
# checked page9
# checked page10
# checked page11
# checked page12
# checked page13
# checked page14
# checked page15
# checked page16
# checked page17
# checked page18
# checked page19

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
# for i, review in enumerate(reviews_list[:5]):
#     print(f"Review {i+1}:")
print(json.dumps(reviews_list[:5], indent=4))
    # print("\n")
# Out:
# [
#     {
#         "web_url": "https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html",
#         "snippet": "A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018The Attachment Diaries\u2019 Review: Love, Sick",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Attachment Diaries",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Attachment Diaries (Movie)",
#                 "rank": 2,
#                 "major": "N"
# ...

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
reviews_df = pd.json_normalize(reviews_list)
reviews_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
# 3  https://www.nytimes.com/2023/04/21/movies/a-to...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Two childhood friends navigate cultural differ...  The New York Times
# 2  Religion comes between two girls falling in lo...  The New York Times
# 3  Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4  A radiant Virginie Efira stars as a Parisian t...  The New York Times
#
#                                             keywords  \
# 0  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1  [{'name': 'subject', 'value': 'Movies', 'rank'...
# ...

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
# Title is between unicode characters \u2018 and \u2019. 
# End string should include " Review" to avoid cutting title early
reviews_df["title"]=reviews_df["headline.main"].apply(lambda st: st[st.find("\u2018")+1:st.find("\u2019 Review")])
reviews_df.head()



# def extract_title(row):
#     match = reviews_list.search(r"\u2018(.*?) Review\u2019", row["headline.main"])
#     if match:
#         return match.group(1)
#     else:
#         return None
    
# df["title"] = df.apply(extract_title, axis=1)
# print(df[["headline.main", "title"]].head())
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
# 3  https://www.nytimes.com/2023/04/21/movies/a-to...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Two childhood friends navigate cultural differ...  The New York Times
# 2  Religion comes between two girls falling in lo...  The New York Times
# 3  Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4  A radiant Virginie Efira stars as a Parisian t...  The New York Times
#
#                                             keywords  \
# 0  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1  [{'name': 'subject', 'value': 'Movies', 'rank'...
# ...

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};" 
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords

# Fix the "keywords" column by converting cells from a list to a string
reviews_df["keywords"] = reviews_df["keywords"].apply(extract_keywords)
reviews_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2017/03/09/movies/the-...
# 196  https://www.nytimes.com/2017/03/09/movies/revi...
# 197  https://www.nytimes.com/2017/03/02/movies/love...
# 198  https://www.nytimes.com/2017/02/16/movies/ever...
# 199  https://www.nytimes.com/2017/02/09/movies/kedi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# ...

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database
titles = reviews_df["title"].to_list()
titles
# Out:
# ['The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'Pamela, a Love Story',
#  'In From the Side',
#  'After Love',
#  'Alcarràs',
#  'Nelly & Nadine',
#  'Lady Chatterley’s Lover',
#  'The Sound of Christmas',
#  'The Inspection',
#  'Bones and All',
#  'My Policeman',
#  'About Fate',
#  'Waiting for Bojangles',
#  'I Love My Dad',
#  'A Love Song',
#  'Alone Together',
#  'Art of Love',
#  'The Wheel',
#  'Thor: Love and Thunder',
#  'Both Sides of the Blade',
#  'Fire of Love',
#  'Love & Gelato',
#  'Stay Prayed Up',
#  'Benediction',
#  'Dinner in America',
#  'In a New York Minute',
#  'Anaïs in Love',
#  'I Love America',
#  'See You Then',
#  'La Mami',
#  'Love After Love',
#  'Deep Water',
#  'Lucy and Desi',
# ...

# %% [markdown]
# ### Access The Movie Database API

# %%
# Prepare The Movie Database query
url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "&api_key=" + tmdb_api_key

# %%
# Create an empty list to store the results
tmdb_movie_list = []

# Create a request counter to sleep the requests after a multiple
# of 50 requests
request_counter = 1

# Loop through the titles
for title in titles:

    # Check if we need to sleep before making a request
    if request_counter % 50 == 0 :
    #and request_counter != 0:
        print("Application is sleeping")
        time.sleep(1)


    # Add 1 to the request counter
    request_counter += 1
    
    # Perform a "GET" request for The Movie Database
    # url = f"https://api.themoviedb.org/3/movie/?api_key={tmdb_api_key}"
    # movie_request = requests.get(url).json()
    response = requests.get(url + title + tmdb_key_string)
    search_response = response.json()
    #print(response)
    #print(json.dumps(search_response, indent=4))
    # Include a try clause to search for the full movie details.
    # Use the except clause to print out a statement if a movie
    # is not found.
    try:
        #search_url = f"https://api.themoviedb.org/3/search/movie?api_key={tmdb_api_key}&query={title}"
        #search_response = requests.get(search_url).json()

        # Get movie id
        movie_id = search_response["results"][0]["id"]

        # Make a request for a the full movie details
        details_url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={tmdb_api_key}"

        # Execute "GET" request with url
        details_response = requests.get(details_url).json()
        
        # Extract the genre names into a list
        genres = []
        #for genre in details_response['genres']:
        #    genres.append(
        #        genre["name"]
        #    )
        genres = [genre["names"] for genre in details_response["genres"]]

        # Extract the spoken_languages' English name into a list
        spoken_languages = []
        spoken_languages = [lang["english_name"] for lang in details_response["spoken_languages"]]

        # Extract the production_countries' name into a list
        production_countries = []
        production_countries = [country["name"]for country in details_response["production_countries"]]

        # Add the relevant data to a dictionary and
        # append it to the tmdb_movies_list list
        movie_details = {
                "title": title,
                "original_title": details_response.get("original_title"),
                "budget": details_response.get("budget"),
                "original_language": details_response.get("original_language"),
                "homepage": details_response.get("homepage"),
                "overview": details_response.get("overview"),
                "popularity": details_response.get("popularity"),
                "runtime": details_response.get("runtime"),
                "revenue": details_response.get("revenue"),
                "release_date": details_response.get("release_date"),
                "vote_average": details_response.get("vote_average"),
                "vote_count": details_response.get("vote_count"),
                "genres": genres,
                "spoken_language": spoken_languages,
                "production_countries": production_countries

        }
        
        tmdb_movie_list.append(movie_details)

        # Print out the title that was found
        print(f"Found details for {title}")

    except:
        print(f"{title} was not found")
# Out:
# The Attachment Diaries was not found
# What’s Love Got to Do With It?’ Probably a Lo was not found
# You Can Live Forever was not found
# A Tourist’s Guide to Love was not found
# Other People’s Children was not found
# One True Loves was not found
# The Lost Weekend: A Love Story was not found
# A Thousand and One was not found
# Your Place or Mine was not found
# Love in the Time of Fentanyl was not found
# Pamela, a Love Story was not found
# In From the Side was not found
# After Love was not found
# Alcarràs was not found
# Nelly & Nadine was not found
# Lady Chatterley’s Lover was not found
# The Sound of Christmas was not found
# The Inspection was not found
# Bones and All was not found
# My Policeman was not found
# About Fate was not found
# Waiting for Bojangles was not found
# I Love My Dad was not found
# A Love Song was not found
# Alone Together was not found
# Art of Love was not found
# The Wheel was not found
# Thor: Love and Thunder was not found
# ...

# %%
# # Create an empty list to store the results
# tmdb_movie_list = []

# # Create a request counter to sleep the requests after a multiple
# # of 50 requests
# request_counter = 1

# # Loop through the titles
# for title in titles:

#     # Check if we need to sleep before making a request
#     if request_counter % 50 == 0 :
#     #and request_counter != 0:
#         print("Application is sleeping")
#         time.sleep(1)


#     # Add 1 to the request counter
#     request_counter += 1
    
#     # Perform a "GET" request for The Movie Database
#     # url = f"https://api.themoviedb.org/3/movie/?api_key={tmdb_api_key}"
#     # movie_request = requests.get(url).json()
#     response = requests.get(url + title + tmdb_key_string)
#     search_response = response.json()

#     # Include a try clause to search for the full movie details.
#     # Use the except clause to print out a statement if a movie
#     # is not found.
#     try:
#         #search_url = f"https://api.themoviedb.org/3/search/movie?api_key={tmdb_api_key}&query={title}"
#         #search_response = requests.get(search_url).json()

#         # Get movie id
#         movie_id = search_response["results"][0]["id"]

#         # Make a request for a the full movie details
#         details_url = f"https://api.themoviedb.org/3/search/movie/{movie_id}?api_key={tmdb_api_key}"

#         # Execute "GET" request with url
#         details_response = requests.get(details_url).json()
        
#         # Extract the genre names into a list
#         genres = []
#         genres = [genre["names"] for genre in details_response["genres"]]

#         # Extract the spoken_languages' English name into a list
#         spoken_languages = []
#         spoken_languages = [lang["english_name"] for lang in details_response["spoken_languages"]]

#         # Extract the production_countries' name into a list
#         production_countries = []
#         production_countries = [country["name"]for country in details_response["production_countries"]]

#         # Add the relevant data to a dictionary and
#         # append it to the tmdb_movies_list list
#         movie_details = {
#                 "title": title,
#                 "original_title": details_response.get("original_title"),
#                 "budget": details_response.get("budget"),
#                 "original_language": details_response.get("original_language"),
#                 "homepage": details_response.get("homepage"),
#                 "overview": details_response.get("overview"),
#                 "popularity": details_response.get("popularity"),
#                 "runtime": details_response.get("runtime"),
#                 "revenue": details_response.get("revenue"),
#                 "release_date": details_response.get("release_date"),
#                 "vote_average": details_response.get("vote_average"),
#                 "vote_count": details_response.get("vote_count"),
#                 "genres": genres,
#                 "spoken_language": spoken_languages,
#                 "production_countries": production_countries

#         }
        
#         tmdb_movie_list.append(movie_details)

#         # Print out the title that was found
#         print(f"Found details for {title}")

#     except:
#         print(f"{title} was not found")
# Out:
# The Attachment Diaries was not found
# What’s Love Got to Do With It?’ Probably a Lo was not found
# You Can Live Forever was not found
# A Tourist’s Guide to Love was not found
# Other People’s Children was not found
# One True Loves was not found
# The Lost Weekend: A Love Story was not found
# A Thousand and One was not found
# Your Place or Mine was not found
# Love in the Time of Fentanyl was not found
# Pamela, a Love Story was not found
# In From the Side was not found
# After Love was not found
# Alcarràs was not found
# Nelly & Nadine was not found
# Lady Chatterley’s Lover was not found
# The Sound of Christmas was not found
# The Inspection was not found
# Bones and All was not found
# My Policeman was not found
# About Fate was not found
# Waiting for Bojangles was not found
# I Love My Dad was not found
# A Love Song was not found
# Alone Together was not found
# Art of Love was not found
# The Wheel was not found
# Thor: Love and Thunder was not found
# ...

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(tmdb_movie_list[:5], indent=4))
# Out:
# []

# %%
# Convert the results to a DataFrame
tmdb_movie_list_df = pd.DataFrame(tmdb_movie_list)
tmdb_movie_list_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
NYT_TMDB_merge_df = pd.merge(reviews_df, tmdb_movie_list_df, on="title", how="inner")
NYT_TMDB_merge_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11848\251845140.py in ?()
#       1 # Merge the New York Times reviews and TMDB DataFrames on title
# ----> 2 NYT_TMDB_merge_df = pd.merge(reviews_df, tmdb_movie_list_df, on="title", how="inner")
#       3 NYT_TMDB_merge_df
#
# c:\Users\Owner\anaconda3\envs\dev\lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     144     copy: bool | None = None,
#     145     indicator: str | bool = False,
#     146     validate: str | None = None,
#     147 ) -> DataFrame:
# --> 148     op = _MergeOperation(
#     149         left,
#     150         right,
#     151         how=how,
#
# ...

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing
columns_to_fix = ["genres", "spoken_language", "production_countries"]


# Create a list of characters to remove
characters_to_remove = [ "[", "]", ""]

# Loop through the list of columns to fix
for column in columns_to_fix:
    # Convert the column to type 'str'
    NYT_TMDB_merge_df[column] = NYT_TMDB_merge_df[column].astype(str)

    # Loop through characters to remove
for char in characters_to_remove:
    NYT_TMDB_merge_df[column] = NYT_TMDB_merge_df[column].str.replace(char, "", regex=False)


# Display the fixed DataFrame
NYT_TMDB_merge_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 12
#       9 # Loop through the list of columns to fix
#      10 for column in columns_to_fix:
#      11     # Convert the column to type 'str'
# ---> 12     NYT_TMDB_merge_df[column] = NYT_TMDB_merge_df[column].astype(str)
#      14     # Loop through characters to remove
#      15 for char in characters_to_remove:
#
# NameError: name 'NYT_TMDB_merge_df' is not defined

# %%
# Drop "byline.person" column
NYT_TMDB_merge_df.drop("byline.person", inplace=True, axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 # Drop "byline.person" column
# ----> 2 NYT_TMDB_merge_df.drop("byline.person", inplace=True, axis=1)
#
# NameError: name 'NYT_TMDB_merge_df' is not defined

# %%
# Delete duplicate rows and reset index
NYT_TMDB_merge_df.drop_duplicates(inplace=True)
NYT_TMDB_merge_df.reset_index(drop=True, inplace=True)
# Out:
#                             title                  original_title  budget  \
# 0          The Attachment Diaries                        El apego       0
# 1            You Can Live Forever            You Can Live Forever       0
# 2                  One True Loves                  One True Loves       0
# 3  The Lost Weekend: A Love Story  The Lost Weekend: A Love Story       0
# 4              A Thousand and One              A Thousand and One       0
#
#                               genre language spoken_languages  \
# 0  Drama, Mystery, Thriller, Horror       es          Spanish
# 1                    Drama, Romance       en  French, English
# 2            Romance, Drama, Comedy       en          English
# 3                       Documentary       en
# 4                             Drama       en          English
#
#                                             homepage  \
# 0
# 1  https://gooddeedentertainment.com/you-can-live...
# 2
# 3
# ...

# %%
# Export data to CSV without the index
